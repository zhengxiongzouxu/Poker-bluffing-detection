# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# Requirement already satisfied: paddleocr>=2.0.1 in c:\users\zouxu\python310\lib\site-packages (2.7.3)
# Requirement already satisfied: shapely in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (2.0.3)
# Requirement already satisfied: scikit-image in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (0.20.0)
# Requirement already satisfied: imgaug in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (1.3.0.post5)
# Requirement already satisfied: lmdb in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (1.4.1)
# Requirement already satisfied: tqdm in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (4.65.2)
# Requirement already satisfied: numpy in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (1.26.4)
# Requirement already satisfied: visualdl in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (2.5.3)
# Requirement already satisfied: rapidfuzz in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (3.8.1)
# Requirement already satisfied: opencv-python<=4.6.0.66 in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (4.6.0.66)
# Requirement already satisfied: opencv-contrib-python<=4.6.0.66 in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (4.6.0.66)
# Requirement already satisfied: cython in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (3.0.10)
# Requirement already satisfied: lxml in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (4.9.2)
# Requirement already satisfied: premailer in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (3.10.0)
# Requirement already satisfied: openpyxl in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (3.1.2)
# Requirement already satisfied: attrdict in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (2.0.1)
# Requirement already satisfied: Pillow>=10.0.0 in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (10.3.0)
# Requirement already satisfied: pyyaml in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (6.0)
# Requirement already satisfied: python-docx in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (4.12.2)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (4.38.0)
# Requirement already satisfied: fire>=0.3.0 in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (0.5.0)
# Requirement already satisfied: pdf2docx in c:\users\zouxu\python310\lib\site-packages (from paddleocr>=2.0.1) (0.5.8)
# Requirement already satisfied: six in c:\users\zouxu\python310\lib\site-packages (from fire>=0.3.0->paddleocr>=2.0.1) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\zouxu\python310\lib\site-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zouxu\python310\lib\site-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.3.2.post1)
# Requirement already satisfied: scipy in c:\users\zouxu\python310\lib\site-packages (from imgaug->paddleocr>=2.0.1) (1.9.1)
# Requirement already satisfied: matplotlib in c:\users\zouxu\python310\lib\site-packages (from imgaug->paddleocr>=2.0.1) (3.6.3)
# Requirement already satisfied: imageio in c:\users\zouxu\python310\lib\site-packages (from imgaug->paddleocr>=2.0.1) (2.26.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (2023.3.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (24.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (0.2)
# Requirement already satisfied: et-xmlfile in c:\users\zouxu\python310\lib\site-packages (from openpyxl->paddleocr>=2.0.1) (1.1.0)
# Requirement already satisfied: PyMuPDF>=1.19.0 in c:\users\zouxu\python310\lib\site-packages (from pdf2docx->paddleocr>=2.0.1) (1.24.2)
# Requirement already satisfied: opencv-python-headless>=4.5 in c:\users\zouxu\python310\lib\site-packages (from pdf2docx->paddleocr>=2.0.1) (4.9.0.80)
# Requirement already satisfied: typing-extensions in c:\users\zouxu\python310\lib\site-packages (from python-docx->paddleocr>=2.0.1) (4.11.0)
# Requirement already satisfied: cssselect in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr>=2.0.1) (1.2.0)
# Requirement already satisfied: cssutils in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr>=2.0.1) (2.10.2)
# Requirement already satisfied: requests in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr>=2.0.1) (2.28.2)
# Requirement already satisfied: cachetools in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr>=2.0.1) (5.3.0)
# Requirement already satisfied: colorama in c:\users\zouxu\python310\lib\site-packages (from tqdm->paddleocr>=2.0.1) (0.4.6)
# Requirement already satisfied: bce-python-sdk in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (0.9.6)
# Requirement already satisfied: flask>=1.1.1 in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (3.0.2)
# Requirement already satisfied: Flask-Babel>=3.0.0 in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (4.0.0)
# Requirement already satisfied: protobuf>=3.20.0 in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (3.20.2)
# Requirement already satisfied: pandas in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (1.5.0)
# Requirement already satisfied: rarfile in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (4.2)
# Requirement already satisfied: psutil in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr>=2.0.1) (5.9.4)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (1.7.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (7.1.0)
# Requirement already satisfied: Babel>=2.12 in c:\users\zouxu\python310\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2.14.0)
# Requirement already satisfied: pytz>=2022.7 in c:\users\zouxu\python310\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2023.4)
# Requirement already satisfied: PyMuPDFb==1.24.1 in c:\users\zouxu\python310\lib\site-packages (from PyMuPDF>=1.19.0->pdf2docx->paddleocr>=2.0.1) (1.24.1)
# Collecting numpy (from paddleocr>=2.0.1)
#   Using cached numpy-1.24.4-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\users\zouxu\python310\lib\site-packages (from bce-python-sdk->visualdl->paddleocr>=2.0.1) (3.20.0)
# Requirement already satisfied: future>=0.6.0 in c:\users\zouxu\python310\lib\site-packages (from bce-python-sdk->visualdl->paddleocr>=2.0.1) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (2024.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\zouxu\python310\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zouxu\python310\lib\site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.1.5)
# Using cached numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.24.4
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zouxu\python310\lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\zouxu\Python310\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\zouxu\Python310\Lib\site-packages\numpy\~~re'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\zouxu\Python310\Lib\site-packages\numpy\~~t'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\zouxu\Python310\Lib\site-packages\numpy\~~nalg'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\zouxu\Python310\Lib\site-packages\numpy\~~ndom'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ray 2.0.0 requires click<=8.0.4,>=7.0, but you have click 8.1.3 which is incompatible.
# ray 2.0.0 requires grpcio<=1.43.0,>=1.28.1; python_version < "3.10", but you have grpcio 1.62.1 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.

# %%
# !pip install paddlepaddle
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.1-cp39-cp39-win_amd64.whl.metadata (8.8 kB)
# Requirement already satisfied: httpx in c:\users\zouxu\python310\lib\site-packages (from paddlepaddle) (0.24.0)
# Requirement already satisfied: numpy>=1.13 in c:\users\zouxu\python310\lib\site-packages (from paddlepaddle) (1.24.4)
# Requirement already satisfied: Pillow in c:\users\zouxu\python310\lib\site-packages (from paddlepaddle) (10.3.0)
# Requirement already satisfied: decorator in c:\users\zouxu\python310\lib\site-packages (from paddlepaddle) (5.1.1)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\zouxu\python310\lib\site-packages (from paddlepaddle) (3.3.0)
# Collecting protobuf<=3.20.2,>=3.1.0 (from paddlepaddle)
#   Downloading protobuf-3.20.2-cp39-cp39-win_amd64.whl.metadata (699 bytes)
# Requirement already satisfied: certifi in c:\users\zouxu\python310\lib\site-packages (from httpx->paddlepaddle) (2024.2.2)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\zouxu\python310\lib\site-packages (from httpx->paddlepaddle) (0.17.0)
# Requirement already satisfied: idna in c:\users\zouxu\python310\lib\site-packages (from httpx->paddlepaddle) (3.4)
# Requirement already satisfied: sniffio in c:\users\zouxu\python310\lib\site-packages (from httpx->paddlepaddle) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\zouxu\python310\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\zouxu\python310\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx->paddlepaddle) (3.6.2)
# Downloading paddlepaddle-2.6.1-cp39-cp39-win_amd64.whl (81.0 MB)
#    ---------------------------------------- 0.0/81.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1
0 MB 11.1 MB/s eta 0:00:02
#    ------------------------------ --------- 61.1/81.0 MB 10.7 MB/s eta 0:00:02
#    ------------------------------ --------- 61.4/81.0 MB 10.4 MB/s eta 0:00:02
#    ------------------------------ --------- 61.6/81.0 MB 10.1 MB/s eta 0:00:02
#    ------------------------------ --------- 62.3/81.0 MB 10.2 MB/s eta 0:00:02
#    ------------------------------ --------- 62.5/81.0 MB 9.8 MB/s eta 0:00:02
#    ------------------------------- -------- 63.0/81.0 MB 10.1 MB/s eta 0:00:02
#    ------------------------------- -------- 63.4/81.0 MB 9.9 MB/s eta 0:00:02
#    ------------------------------- -------- 63.7/81.0 MB 9.6 MB/s eta 0:00:02
#    ------------------------------- -------- 63.8/81.0 MB 9.8 MB/s eta 0:00:02
#    ------------------------------- -------- 64.0/81.0 MB 9.2 MB/s eta 0:00:02
#    ------------------------------- -------- 64.7/81.0 MB 9.4 MB/s eta 0:00:02
#    -------------------------------- ------- 64.8/81.0 MB 9.0 MB/s eta 0:00:02
#    -------------------------------- ------- 65.3/81.0 MB 9.2 MB/s eta 0:00:02
#    -------------------------------- ------- 65.7/81.0 MB 9.9 MB/s eta 0:00:02
#    -------------------------------- ------- 66.3/81.0 MB 9.4 MB/s eta 0:00:02
#    --------------------------------- ------ 66.9/81.0 MB 9.2 MB/s eta 0:00:02
#    --------------------------------- ------ 67.2/81.0 MB 9.2 MB/s eta 0:00:02
#    --------------------------------- ------ 67.4/81.0 MB 9.1 MB/s eta 0:00:02
#    --------------------------------- ------ 67.9/81.0 MB 9.1 MB/s eta 0:00:02
#    --------------------------------- ------ 68.4/81.0 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 69.0/81.0 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 69.5/81.0 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 69.9/81.0 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 70.6/81.0 MB 9.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 71.2/81.0 MB 9.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 71.9/81.0 MB 9.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 72.3/81.0 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 72.9/81.0 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 73.4/81.0 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 73.9/81.0 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 74.7/81.0 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 75.0/81.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 75.7/81.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 76.1/81.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 76.4/81.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 76.8/81.0 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 77.6/81.0 MB 11.5 MB/s eta 0:00:01
#    -------------------------------------- - 78.0/81.0 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 78.7/81.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  79.6/81.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  80.0/81.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  80.5/81.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  80.9/81.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  80.9/81.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 81.0/81.0 MB 10.9 MB/s eta 0:00:00
# Downloading protobuf-3.20.2-cp39-cp39-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.2 kB ? eta -:--:--
#    ----------------------- --------------- 542.7/904.2 kB 35.5 MB/s eta 0:00:01
#    ----------------------------- --------- 686.1/904.2 kB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 904.2/904.2 kB 9.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: protobuf, astor, paddlepaddle
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# Successfully installed astor-0.8.1 paddlepaddle-2.6.1 protobuf-3.20.2
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zouxu\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ray 2.0.0 requires click<=8.0.4,>=7.0, but you have click 8.1.3 which is incompatible.
# ray 2.0.0 requires grpcio<=1.43.0,>=1.28.1; python_version < "3.10", but you have grpcio 1.62.1 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.14.0 requires absl-py<2.0.0,>=0.9, but you have absl-py 2.1.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.

# %%
# !pip install --upgrade paddleocr
# !pip install --upgrade numpy

# %%
from paddleocr import PaddleOCR

# 2. 声明PaddleOCR类
ocr = PaddleOCR()  

result = ocr.ocr('C:/Users/zouxu/OneDrive/Desktop/p poker/paddleOcr/text_detection/1.jpg', rec=False)
result = ocr.ocr(img_path, rec=False)
print(f"The predicted text box of {img_path} are follows.")
print(result)
# Out:
# [2024/04/18 22:37:47] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\zouxu/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\zouxu/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\zouxu\\Python310\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='C:\\Users\\zouxu/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/04/18 22:37:47] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/04/18 22:37:47] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# The predicted text box of C:/Users/zouxu/OneDrive/Desktop/p poker/paddleOcr/text_detection/1.jpg are follows.
# [[[[163.0, 706.0], [260.0, 704.0], [260.0, 719.0], [163.0, 719.0]], [[1196.0, 674.0], [1255.0, 674.0], [1255.0, 692.0], [1196.0, 692.0]], [[1019.0, 671.0], [1115.0, 674.0], [1114.0, 696.0], [1018.0, 693.0]], [[357.0, 672.0], [392.0, 672.0], [392.0, 692.0], [357.0, 692.0]], [[164.0, 671.0], [279.0, 671.0], [279.0, 695.0], [164.0, 695.0]], [[1019.0, 642.0], [1129.0, 642.0], [1129.0, 666.0], [1019.0, 666.0]], [[368.0, 642.0], [396.0, 642.0], [396.0, 658.0], [368.0, 658.0]], [[172.0, 635.0], [301.0, 635.0], [301.0, 667.0], [172.0, 667.0]], [[91.0, 566.0], [149.0, 566.0], [149.0, 586.0], [91.0, 586.0]], [[291.0, 535.0], [325.0, 535.0], [325.0, 556.0], [291.0, 556.0]], [[96.0, 531.0], [203.0, 531.0], [203.0, 559.0], [96.0, 559.0]], [[312.0, 506.0], [327.0, 506.0], [327.0, 519.0], [312.0, 519.0]], [[101.0, 496.0], [211.0, 496.0], [211.0, 528.0], [101.0, 528.0]], [[95.0, 451.0], [195.0, 451.0], [195.0, 474.0], [95.0, 474.0]], [[280.0, 421.0], [327.0, 421.0], [327.0, 441.0], [280.0, 441.0]], [[92.0, 414.0], [215.0, 417.0], [214.0, 445.0], [92.0, 442.0]], [[312.0, 390.0], [327.0, 390.0], [327.0, 402.0], [312.0, 402.0]], [[103.0, 382.0], [233.0, 382.0], [233.0, 414.0], [103.0, 414.0]], [[965.0, 195.0], [1136.0, 218.0], [1132.0, 246.0], [961.0, 223.0]], [[967.0, 155.0], [1142.0, 173.0], [1137.0, 216.0], [963.0, 197.0]], [[1194.0, 19.0], [1274.0, 27.0], [1271.0, 55.0], [1191.0, 47.0]]]]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# 在notebook中使用matplotlib.pyplot绘图时，需要添加该命令进行显示
# %matplotlib inline

# 4. 可视化检测结果
image = cv2.imread(img_path)
boxes = [line[0] for line in result]
for box in result:
    box = np.reshape(np.array(box), [-1, 1, 2]).astype(np.int64)
    image = cv2.polylines(np.array(image), [box], True, (255, 0, 0), 2)

# 画出读取的图片
plt.figure(figsize=(10, 10))
plt.imshow(image)

# %% [markdown]
# # DB model

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from paddleocr.ppocr.modeling.backbones.det_mobilenet_v3 import MobileNetV3

# %%
import paddle 

fake_inputs = paddle.randn([1, 3, 640, 640], dtype="float32")

# 1. 声明Backbone
model_backbone = MobileNetV3()
model_backbone.eval()

# 2. 执行预测
outs = model_backbone(fake_inputs)

# 3. 打印网络结构
print(model_backbone)

# 4. 打印输出特征形状
for idx, out in enumerate(outs):
    print("The index is ", idx, "and the shape of output is ", out.shape)
# Out:
# MobileNetV3(
#   (conv): ConvBNLayer(
#     (conv): Conv2D(3, 8, kernel_size=[3, 3], stride=[2, 2], padding=1, data_format=NCHW)
#     (bn): BatchNorm()
#   )
#   (stage0): Sequential(
#     (0): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(8, 8, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(8, 8, kernel_size=[3, 3], padding=1, groups=8, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(8, 8, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (1): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(8, 32, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(32, 32, kernel_size=[3, 3], stride=[2, 2], padding=1, groups=32, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(32, 16, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (2): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(16, 40, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(40, 40, kernel_size=[3, 3], padding=1, groups=40, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(40, 16, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#   )
#   (stage1): Sequential(
#     (0): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(16, 40, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(40, 40, kernel_size=[5, 5], stride=[2, 2], padding=2, groups=40, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(40, 10, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(10, 40, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(40, 24, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (1): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(24, 64, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(64, 64, kernel_size=[5, 5], padding=2, groups=64, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(64, 16, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(16, 64, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(64, 24, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (2): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(24, 64, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(64, 64, kernel_size=[5, 5], padding=2, groups=64, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(64, 16, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(16, 64, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(64, 24, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#   )
#   (stage2): Sequential(
#     (0): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(24, 120, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(120, 120, kernel_size=[3, 3], stride=[2, 2], padding=1, groups=120, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(120, 40, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (1): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(40, 104, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(104, 104, kernel_size=[3, 3], padding=1, groups=104, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(104, 40, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (2): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(40, 96, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(96, 96, kernel_size=[3, 3], padding=1, groups=96, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(96, 40, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (3): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(40, 96, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(96, 96, kernel_size=[3, 3], padding=1, groups=96, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(96, 40, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (4): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(40, 240, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(240, 240, kernel_size=[3, 3], padding=1, groups=240, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(240, 60, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(60, 240, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(240, 56, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (5): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(56, 336, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(336, 336, kernel_size=[3, 3], padding=1, groups=336, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(336, 84, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(84, 336, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(336, 56, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#   )
#   (stage3): Sequential(
#     (0): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(56, 336, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(336, 336, kernel_size=[5, 5], stride=[2, 2], padding=2, groups=336, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(336, 84, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(84, 336, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(336, 80, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (1): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(80, 480, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(480, 480, kernel_size=[5, 5], padding=2, groups=480, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(480, 120, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(120, 480, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(480, 80, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (2): ResidualUnit(
#       (expand_conv): ConvBNLayer(
#         (conv): Conv2D(80, 480, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (bottleneck_conv): ConvBNLayer(
#         (conv): Conv2D(480, 480, kernel_size=[5, 5], padding=2, groups=480, data_format=NCHW)
#         (bn): BatchNorm()
#       )
#       (mid_se): SEModule(
#         (avg_pool): AdaptiveAvgPool2D(output_size=1)
#         (conv1): Conv2D(480, 120, kernel_size=[1, 1], data_format=NCHW)
#         (conv2): Conv2D(120, 480, kernel_size=[1, 1], data_format=NCHW)
#       )
#       (linear_conv): ConvBNLayer(
#         (conv): Conv2D(480, 80, kernel_size=[1, 1], data_format=NCHW)
#         (bn): BatchNorm()
#       )
#     )
#     (3): ConvBNLayer(
#       (conv): Conv2D(80, 480, kernel_size=[1, 1], data_format=NCHW)
#       (bn): BatchNorm()
#     )
#   )
# )
# The index is  0 and the shape of output is  [1, 16, 160, 160]
# The index is  1 and the shape of output is  [1, 24, 80, 80]
# The index is  2 and the shape of output is  [1, 56, 40, 40]
# The index is  3 and the shape of output is  [1, 480, 20, 20]

# %%
import paddle
from paddle import nn
import paddle.nn.functional as F
from paddle import ParamAttr

class DBFPN(nn.Layer):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(DBFPN, self).__init__()
        self.out_channels = out_channels

        # DBFPN详细实现参考： https://github.com/PaddlePaddle/PaddleOCRblob/release%2F2.4/ppocr/modeling/necks/db_fpn.py

    def forward(self, x):
        c2, c3, c4, c5 = x

        in5 = self.in5_conv(c5)
        in4 = self.in4_conv(c4)
        in3 = self.in3_conv(c3)
        in2 = self.in2_conv(c2)

        # 特征上采样
        out4 = in4 + F.upsample(
            in5, scale_factor=2, mode="nearest", align_mode=1)  # 1/16
        out3 = in3 + F.upsample(
            out4, scale_factor=2, mode="nearest", align_mode=1)  # 1/8
        out2 = in2 + F.upsample(
            out3, scale_factor=2, mode="nearest", align_mode=1)  # 1/4

        p5 = self.p5_conv(in5)
        p4 = self.p4_conv(out4)
        p3 = self.p3_conv(out3)
        p2 = self.p2_conv(out2)

        # 特征上采样
        p5 = F.upsample(p5, scale_factor=8, mode="nearest", align_mode=1)
        p4 = F.upsample(p4, scale_factor=4, mode="nearest", align_mode=1)
        p3 = F.upsample(p3, scale_factor=2, mode="nearest", align_mode=1)

        fuse = paddle.concat([p5, p4, p3, p2], axis=1)
        return fuse

# %%
import paddle 

# 1. 从PaddleOCR中import DBFPN
from ppocr.modeling.necks.db_fpn import DBFPN

# 2. 获得Backbone网络输出结果
fake_inputs = paddle.randn([1, 3, 640, 640], dtype="float32")
model_backbone = MobileNetV3()
in_channles = model_backbone.out_channels

# 3. 声明FPN网络
model_fpn = DBFPN(in_channels=in_channles, out_channels=256)

# 4. 打印FPN网络
print(model_fpn)

# 5. 计算得到FPN结果输出
outs = model_backbone(fake_inputs)
fpn_outs = model_fpn(outs)

# 6. 打印FPN输出特征形状
print(f"The shape of fpn outs {fpn_outs.shape}")
# Out:
# DBFPN(
#   (in2_conv): Conv2D(16, 256, kernel_size=[1, 1], data_format=NCHW)
#   (in3_conv): Conv2D(24, 256, kernel_size=[1, 1], data_format=NCHW)
#   (in4_conv): Conv2D(56, 256, kernel_size=[1, 1], data_format=NCHW)
#   (in5_conv): Conv2D(480, 256, kernel_size=[1, 1], data_format=NCHW)
#   (p5_conv): Conv2D(256, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)
#   (p4_conv): Conv2D(256, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)
#   (p3_conv): Conv2D(256, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)
#   (p2_conv): Conv2D(256, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)
# )
# The shape of fpn outs [1, 256, 160, 160]

# %%
import math
import paddle
from paddle import nn
import paddle.nn.functional as F
from paddle import ParamAttr

class DBHead(nn.Layer):
    """
    Differentiable Binarization (DB) for text detection:
        see https://arxiv.org/abs/1911.08947
    args:
        params(dict): super parameters for build DB network
    """

    def __init__(self, in_channels, k=50, **kwargs):
        super(DBHead, self).__init__()
        self.k = k

        # DBHead详细实现参考 https://github.com/PaddlePaddle/PaddleOCR/blob/release%2F2.4/ppocr/modeling/heads/det_db_head.py

    def step_function(self, x, y):
        # 可微二值化实现，通过概率图和阈值图计算文本分割二值图
        return paddle.reciprocal(1 + paddle.exp(-self.k * (x - y)))

    def forward(self, x, targets=None):
        shrink_maps = self.binarize(x)
        if not self.training:
            return {'maps': shrink_maps}

        threshold_maps = self.thresh(x)
        binary_maps = self.step_function(shrink_maps, threshold_maps)
        y = paddle.concat([shrink_maps, threshold_maps, binary_maps], axis=1)
        return {'maps': y}

# %%
# 1. 从PaddleOCR中imort DBHead
from ppocr.modeling.heads.det_db_head import DBHead
import paddle 

# 2. 计算DBFPN网络输出结果
fake_inputs = paddle.randn([1, 3, 640, 640], dtype="float32")
model_backbone = MobileNetV3()
in_channles = model_backbone.out_channels
model_fpn = DBFPN(in_channels=in_channles, out_channels=256)
outs = model_backbone(fake_inputs)
fpn_outs = model_fpn(outs)

# 3. 声明Head网络
model_db_head = DBHead(in_channels=256)

# 4. 打印DBhead网络
print(model_db_head)

# 5. 计算Head网络的输出
db_head_outs = model_db_head(fpn_outs)
print(f"The shape of fpn outs {fpn_outs.shape}")
print(f"The shape of DB head outs {db_head_outs['maps'].shape}")
# Out:
# DBHead(
#   (binarize): Head(
#     (conv1): Conv2D(256, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)
#     (conv_bn1): BatchNorm()
#     (conv2): Conv2DTranspose(64, 64, kernel_size=[2, 2], stride=[2, 2], data_format=NCHW)
#     (conv_bn2): BatchNorm()
#     (conv3): Conv2DTranspose(64, 1, kernel_size=[2, 2], stride=[2, 2], data_format=NCHW)
#   )
#   (thresh): Head(
#     (conv1): Conv2D(256, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)
#     (conv_bn1): BatchNorm()
#     (conv2): Conv2DTranspose(64, 64, kernel_size=[2, 2], stride=[2, 2], data_format=NCHW)
#     (conv_bn2): BatchNorm()
#     (conv3): Conv2DTranspose(64, 1, kernel_size=[2, 2], stride=[2, 2], data_format=NCHW)
#   )
# )
# The shape of fpn outs [1, 256, 160, 160]
# The shape of DB head outs [1, 3, 640, 640]

# %%
# !pip install paddleocr
# Out:
# Requirement already satisfied: paddleocr in c:\users\zouxu\python310\lib\site-packages (2.7.3)
# Requirement already satisfied: shapely in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (2.0.3)
# Requirement already satisfied: scikit-image in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (0.20.0)
# Requirement already satisfied: imgaug in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (1.4.1)
# Requirement already satisfied: tqdm in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (4.65.2)
# Requirement already satisfied: numpy in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (1.24.4)
# Requirement already satisfied: visualdl in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (2.5.3)
# Requirement already satisfied: rapidfuzz in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (3.8.1)
# Requirement already satisfied: opencv-python<=4.6.0.66 in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: opencv-contrib-python<=4.6.0.66 in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: cython in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (3.0.10)
# Requirement already satisfied: lxml in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (4.9.2)
# Requirement already satisfied: premailer in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (3.10.0)
# Requirement already satisfied: openpyxl in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (3.1.2)
# Requirement already satisfied: attrdict in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (2.0.1)
# Requirement already satisfied: Pillow>=10.0.0 in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (10.3.0)
# Requirement already satisfied: pyyaml in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (6.0)
# Requirement already satisfied: python-docx in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (4.12.2)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (4.38.0)
# Requirement already satisfied: fire>=0.3.0 in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (0.5.0)
# Requirement already satisfied: pdf2docx in c:\users\zouxu\python310\lib\site-packages (from paddleocr) (0.5.8)
# Requirement already satisfied: six in c:\users\zouxu\python310\lib\site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\zouxu\python310\lib\site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zouxu\python310\lib\site-packages (from beautifulsoup4->paddleocr) (2.3.2.post1)
# Requirement already satisfied: scipy in c:\users\zouxu\python310\lib\site-packages (from imgaug->paddleocr) (1.9.1)
# Requirement already satisfied: matplotlib in c:\users\zouxu\python310\lib\site-packages (from imgaug->paddleocr) (3.6.3)
# Requirement already satisfied: imageio in c:\users\zouxu\python310\lib\site-packages (from imgaug->paddleocr) (2.26.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr) (3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr) (2023.3.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr) (24.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\zouxu\python310\lib\site-packages (from scikit-image->paddleocr) (0.2)
# Requirement already satisfied: et-xmlfile in c:\users\zouxu\python310\lib\site-packages (from openpyxl->paddleocr) (1.1.0)
# Requirement already satisfied: PyMuPDF>=1.19.0 in c:\users\zouxu\python310\lib\site-packages (from pdf2docx->paddleocr) (1.24.2)
# Requirement already satisfied: opencv-python-headless>=4.5 in c:\users\zouxu\python310\lib\site-packages (from pdf2docx->paddleocr) (4.9.0.80)
# Requirement already satisfied: typing-extensions in c:\users\zouxu\python310\lib\site-packages (from python-docx->paddleocr) (4.11.0)
# Requirement already satisfied: cssselect in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr) (1.2.0)
# Requirement already satisfied: cssutils in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr) (2.10.2)
# Requirement already satisfied: requests in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr) (2.28.2)
# Requirement already satisfied: cachetools in c:\users\zouxu\python310\lib\site-packages (from premailer->paddleocr) (5.3.0)
# Requirement already satisfied: colorama in c:\users\zouxu\python310\lib\site-packages (from tqdm->paddleocr) (0.4.6)
# Requirement already satisfied: bce-python-sdk in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (0.9.6)
# Requirement already satisfied: flask>=1.1.1 in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (3.0.2)
# Requirement already satisfied: Flask-Babel>=3.0.0 in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (4.0.0)
# Requirement already satisfied: protobuf>=3.20.0 in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (3.20.2)
# Requirement already satisfied: pandas in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (1.5.0)
# Requirement already satisfied: rarfile in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (4.2)
# Requirement already satisfied: psutil in c:\users\zouxu\python310\lib\site-packages (from visualdl->paddleocr) (5.9.4)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (1.7.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\zouxu\python310\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (7.1.0)
# Requirement already satisfied: Babel>=2.12 in c:\users\zouxu\python310\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2.14.0)
# Requirement already satisfied: pytz>=2022.7 in c:\users\zouxu\python310\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2023.4)
# Requirement already satisfied: PyMuPDFb==1.24.1 in c:\users\zouxu\python310\lib\site-packages (from PyMuPDF>=1.19.0->pdf2docx->paddleocr) (1.24.1)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\users\zouxu\python310\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (3.20.0)
# Requirement already satisfied: future>=0.6.0 in c:\users\zouxu\python310\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zouxu\python310\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zouxu\python310\lib\site-packages (from requests->premailer->paddleocr) (2024.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\zouxu\python310\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr) (3.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zouxu\python310\lib\site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr) (2.1.5)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\zouxu\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zouxu\python310\lib\site-packages)

# %%
from paddleocr import PaddleOCR, draw_ocrc:\Users\zouxu\.paddleocr\whl\det\en\en_PP-OCRv3_det_infer\en_PP-OCRv3_det_infer.tar

# 创建一个OCR对象，lang参数为'ch'代表中文模型，如果处理英文图像可以设置为'en'
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # 需要检测文本方向

# 使用OCR进行文本检测
img_path = 'C:/Users/zouxu/OneDrive/Desktop/p poker/paddleOcr/text_detection/1.jpg'  # 替换为你的图片路径
result = ocr.ocr(img_path, cls=True)

# 输出检测结果
for line in result:
    print(line)

# 可视化结果
image = draw_ocr(img_path, result, font_path='path_to_font')  # 替换为字体文件的路径
cv2.imwrite('result.jpg', image)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to C:\Users\zouxu/.paddleocr/whl\det\en\en_PP-OCRv3_det_infer\en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:10<00:00, 364kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to C:\Users\zouxu/.paddleocr/whl\rec\en\en_PP-OCRv4_rec_infer\en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [04:50<00:00, 35.2kiB/s]
# [2024/04/25 11:26:34] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\zouxu/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\zouxu/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\zouxu\\Python310\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\zouxu/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/04/25 11:26:35] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.205657958984375
# [2024/04/25 11:26:35] ppocr DEBUG: cls num  : 24, elapsed : 0.10652637481689453
# [2024/04/25 11:26:36] ppocr DEBUG: rec_res num  : 24, elapsed : 0.3839852809906006
# [[[[1194.0, 17.0], [1275.0, 27.0], [1271.0, 55.0], [1191.0, 45.0]], ('CARD', 0.9976798295974731)], [[[968.0, 153.0], [1143.0, 176.0], [1137.0, 217.0], [962.0, 194.0]], ('TEXAS', 0.9977942705154419)], [[[965.0, 196.0], [1134.0, 218.0], [1131.0, 245.0], [962.0, 223.0]], ('CARDHOUSE', 0.9930824637413025)], [[[101.0, 381.0], [237.0, 381.0], [237.0, 413.0], [101.0, 413.0]], ('104', 0.970585286617279)], [[[312.0, 390.0], [327.0, 390.0], [327.0, 404.0], [312.0, 404.0]], ('HJ', 0.9833256006240845)], [[[95.0, 418.0], [213.0, 418.0], [213.0, 441.0], [95.0, 441.0]], ('PRESTIGE', 0.9970167875289917)], [[[280.0, 421.0], [327.0, 421.0], [327.0, 439.0], [280.0, 439.0]], ('$1.7K', 0.9967588186264038)], [[[95.0, 451.0], [192.0, 451.0], [192.0, 470.0], [95.0, 470.0]], ('CALLED$5', 0.9959959387779236)], [[[101.0, 495.0], [236.0, 495.0], [236.0, 528.0], [101.0, 528.0]], ('105', 0.9841134548187256)], [[[309.0, 503.0], [329.0, 503.0], [329.0, 521.0], [309.0, 521.0]], ('Co', 0.524432897567749)], [[[48.0, 533.0], [67.0, 533.0], [67.0, 553.0], [48.0, 553.0]], ('9', 0.9934224486351013)], [[[96.0, 533.0], [201.0, 533.0], [201.0, 556.0], [96.0, 556.0]], ('CHRISW', 0.9943588376045227)], [[[291.0, 535.0], [325.0, 535.0], [325.0, 555.0], [291.0, 555.0]], ('$2K', 0.9993051886558533)], [[[89.0, 566.0], [148.0, 566.0], [148.0, 585.0], [89.0, 585.0]], ('OLDED', 0.9804441332817078)], [[[171.0, 634.0], [303.0, 634.0], [303.0, 666.0], [171.0, 666.0]], ('K2*', 0.8680521845817566)], [[[364.0, 641.0], [397.0, 641.0], [397.0, 660.0], [364.0, 660.0]], ('BTN', 0.7911360859870911)], [[[1020.0, 643.0], [1069.0, 643.0], [1069.0, 663.0], [1020.0, 663.0]], ('POT', 0.9959003329277039)], [[[1080.0, 642.0], [1128.0, 642.0], [1128.0, 666.0], [1080.0, 666.0]], ('$12', 0.9999783039093018)], [[[163.0, 671.0], [279.0, 671.0], [279.0, 694.0], [163.0, 694.0]], ('OPTIMIZE', 0.9976875185966492)], [[[357.0, 672.0], [393.0, 672.0], [393.0, 692.0], [357.0, 692.0]], ('$2K', 0.9985105395317078)], [[[1021.0, 674.0], [1113.0, 674.0], [1113.0, 692.0], [1021.0, 692.0]], ('$2/$5NLH', 0.9701013565063477)], [[[1196.0, 674.0], [1253.0, 674.0], [1253.0, 692.0], [1196.0, 692.0]], ('HAND2', 0.9952162504196167)], [[[164.0, 705.0], [261.0, 705.0], [261.0, 719.0], [164.0, 719.0]], ('$5TOCALL', 0.9821710586547852)]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 15
#      12     print(line)
#      14 # 可视化结果
# ---> 15 image = draw_ocr(img_path, result, font_path='path_to_font')  # 替换为字体文件的路径
#      16 cv2.imwrite('result.jpg', image)
#
# File c:\Users\zouxu\Python310\lib\site-packages\paddleocr\tools\infer\utility.py:390, in draw_ocr(image, boxes, txts, scores, drop_score, font_path)
#     387     if scores is not None and (scores[i] < drop_score or
#     388                                math.isnan(scores[i])):
#     389         continue
# --> 390     box = np.reshape(np.array(boxes[i]), [-1, 1, 2]).astype(np.int64)
#     391     image = cv2.polylines(np.array(image), [box], True, (255, 0, 0), 2)
#     392 if txts is not None:
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (23, 2) + inhomogeneous part.
